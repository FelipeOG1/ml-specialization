# %%
from main import NameTokenaizer, Model
import os
data = os.path.join("data", "names.txt")
names = open(data, "r").read().splitlines()
# Out:
# tensor(0.2802)

# %%
# Out:
# tensor([[ 6.9596,  6.7118],
#         [ 3.5668, 14.6231],
#         [13.2945, 10.4445],
#         [12.7733, 14.1493],
#         [ 4.7482,  7.4437],
#         [ 6.7862, 15.5310],
#         [ 9.1620, 11.7790],
#         [ 7.3871, 14.1194],
#         [12.7398,  9.7300],
#         [ 5.2899, 12.7274]])
